# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %% [markdown]
# work on the correlation matrix and clustering to find optimal pairs
# find way with monte carlo simulation to record the returns on individual assets
# maybe look at optimizing each asset with its own thresholds?
# trades histogram or kd plot with percent returns
# find way to backtest and show how a portfolio would have performed over historical data

# %%
def calculate_zscore(price_data, market):
            spread_series = price_data[market]
            mean = spread_series.rolling(window=200).mean()
            std = spread_series.rolling(window=200).std()
            price_data[f'z_score_{market}'] = (spread_series - mean) / std

price_data = pd.read_csv('./data_15m.csv')

for market in price_data:
    if market == 'time':
        continue
    calculate_zscore(price_data, market)
price_data.to_csv('zscore_15m.csv')

# %%
price_data.tail()
# Out:
#                      time  BTCUSDT  ETHUSDT   SOLUSDT  BCHUSDT  XRPUSDT  \
# 7795  2024-06-13 22:30:00  66940.4  3481.50  148.0001   435.02  0.47901
# 7796  2024-06-13 22:45:00  66868.7  3480.14  148.0852   434.31  0.47921
# 7797  2024-06-13 23:00:00  66714.5  3464.62  147.1330   431.91  0.47652
# 7798  2024-06-13 23:15:00  66855.1  3474.08  147.6253   432.27  0.47756
# 7799  2024-06-13 23:30:00  66830.3  3472.17  147.4335   431.93  0.47755
#
#       LTCUSDT  ADAUSDT  LINKUSDT  DOGEUSDT  ...  z_score_LTCUSDT  \
# 7795    79.18  0.42239    15.203  0.141726  ...         1.411902
# 7796    79.11  0.42220    15.199  0.141734  ...         1.303976
# 7797    78.90  0.42014    15.101  0.140785  ...         1.007577
# 7798    79.09  0.42139    15.147  0.141313  ...         1.256873
# 7799    79.12  0.42185    15.164  0.141265  ...         1.285746
#
#       z_score_ADAUSDT  z_score_LINKUSDT  z_score_DOGEUSDT  z_score_WIFUSDT  \
# 7795        -1.052582         -0.803336         -0.300171        -1.643433
# 7796        -1.080459         -0.818345         -0.304862        -1.665058
# 7797        -1.378392         -1.096815         -0.598187        -1.952169
# 7798        -1.196280         -0.970020         -0.444629        -1.793543
# 7799        -1.129052         -0.926864         -0.465641        -1.724459
#
#       z_score_MATICUSDT  z_score_UNIUSDT  z_score_AAVEUSDT  z_score_DYDXUSDT  \
# 7795          -1.769741         0.993871         -1.527186         -1.617772
# 7796          -1.790801         0.885986         -1.514959         -1.601440
# 7797          -2.075019         0.697546         -1.711225         -1.769733
# 7798          -1.841852         0.870529         -1.611795         -1.604361
# 7799          -1.782238         0.935557         -1.610376         -1.551713
#
#       z_score_CRVUSDT
# 7795        -1.038795
# 7796        -1.033456
# 7797        -1.070342
# 7798        -1.025055
# 7799        -0.975402
#
# [5 rows x 31 columns]

# %%
price_data = pd.read_csv('./data_1H.csv')

for market in price_data:
    if market == 'time':
        continue
    calculate_zscore(price_data, market)
price_data.to_csv('zscore_1H.csv')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=price_data['time'], y=price_data['z_score_ETHUSDT'], data=price_data, marker='o')

# Customize the plot
plt.title('Time Series Plot of Value')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(price_data['z_score_ETHUSDT'], fill=True)

# Customize the plot
plt.title('KDE Plot of Value')
plt.xlabel('Value')
plt.ylabel('Density')
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=price_data['time'], y=price_data['z_score_WIFUSDT'], data=price_data, marker='o')

# Customize the plot
plt.title('Time Series Plot of Value')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(price_data['z_score_WIFUSDT'], fill=True)

# Customize the plot
plt.title('KDE Plot of Value')
plt.xlabel('Value')
plt.ylabel('Density')
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=price_data['time'], y=price_data['z_score_UNIUSDT'], data=price_data, marker='o')

# Customize the plot
plt.title('Time Series Plot of Value')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create the KDE plot
plt.figure(figsize=(10, 6))
sns.kdeplot(price_data['z_score_UNIUSDT'], fill=True)

# Customize the plot
plt.title('KDE Plot of Value')
plt.xlabel('Value')
plt.ylabel('Density')
plt.tight_layout()

# Show the plot
plt.show()
